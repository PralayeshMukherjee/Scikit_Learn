# %%
import sklearn
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("placement.csv")

# %%
df.head(3)
# Out:
#    Unnamed     iq  cgpa  placement
# 0        0  230.6   2.1          1
# 1        1  176.8   5.4          1
# 2        2  202.9   6.5          0
