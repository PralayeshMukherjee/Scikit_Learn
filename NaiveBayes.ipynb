# %% [markdown]
# ### There are 3 types of Naive Bayes algorithm in Scikit_learn
# #### 1) GaussianNB → Continuous data
# #### 2) MultinomialNB → Text classification, word counts
# #### 3) BernoulliNB → Binary features

# %%
import pandas as pd
