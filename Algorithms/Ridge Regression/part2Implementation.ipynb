# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_regression

# %%
x,y = make_regression(n_samples=100,n_features=1,n_informative=1,n_targets=1,noise=20,random_state=13)
#it has 100 samples(data/rows), 1 feature(input column),1 informative feature,1 target(output column),noise 20 means the data is not perfectly linear,random state is for reproducibility means it will generate the same data every time we run the code
#informative feature means the feature that is actually useful for predicting the target variable
