# %%
import pandas as pd
import numpy as np

# %%
class simpleLinearRegression:
    def __init__(self):
        self.m = None
        self.b = None
    
    def fit(self,x_train,y_train):
        pass
    def predict(self,x_test):
        pass
