# %% [markdown]
# ## Normalization:
#
# their are 4 types of normalization
#
# i) MinMaxScalling
#
# ii) Mean Normalization
#
# iii) Max Abolute
#
# iv) Robust Scalling

# %% [markdown]
# ### Mean Normalization
