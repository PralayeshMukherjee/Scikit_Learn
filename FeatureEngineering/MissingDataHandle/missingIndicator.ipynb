# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('indicator.csv',usecols=['Age','Fare','Survived'])

# %%
df.head(3)
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Age       714 non-null    float64
#  2   Fare      891 non-null    float64
# dtypes: float64(2), int64(1)
# memory usage: 21.0 KB

# %%
x = df.iloc[:,1:3]
y = df.iloc[:,0]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.isnull().sum()
# Out:
# Age     140
# Fare      0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
t1 = ColumnTransformer(
    transformers=[
        ('impute',SimpleImputer(strategy='mean'),[0])
    ],
    remainder='passthrough'
)

# %%
logistic = LogisticRegression()
pipe = Pipeline([
    ('t1',t1),
    ('t2',logistic)
])

# %%
pipe.fit(x_train,y_train)
y_pred = pipe.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.6480446927374302

# %%
from sklearn.impute import MissingIndicator

# %%
t2 = ColumnTransformer(
    transformers=[
        ('indicator',MissingIndicator(),[0])
    ],
    remainder='passthrough'
)

# %%
pipe2 = Pipeline([
    ('t2',t2),
    ('logistic',logistic)
])

# %%
y_pred2 = pipe2.fit_predict(x_train,y_train)
accuracy_score(y_test,y_pred2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\rajmu\OneDrive\Desktop\ML\Scikit_Learn\.venv\Lib\site-packages\sklearn\utils\_available_if.py:32, in _AvailableIfDescriptor._check(self, obj, owner)
#      31 try:
# ---> 32     check_result = self.check(obj)
#      33 except Exception as e:
#
# File c:\Users\rajmu\OneDrive\Desktop\ML\Scikit_Learn\.venv\Lib\site-packages\sklearn\pipeline.py:45, in _final_estimator_has.<locals>.check(self)
#      43 def check(self):
#      44     # raise original `AttributeError` if `attr` does not exist
# ---> 45     getattr(self._final_estimator, attr)
#      46     return True
#
# AttributeError: 'LogisticRegression' object has no attribute 'fit_predict'
#
# The above exception was the direct cause of the following exception:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 y_pred2 = pipe2.fit_predict(x_train,y_train)
#       2 accuracy_score(y_test,y_pred2)
#
# File c:\Users\rajmu\OneDrive\Desktop\ML\Scikit_Learn\.venv\Lib\site-packages\sklearn\utils\_available_if.py:43, in _AvailableIfDescriptor.__get__(self, obj, owner)
#      39 def __get__(self, obj, owner=None):
#      40     if obj is not None:
#      41         # delegate only on instances, not the classes.
#      42         # this is to allow access to the docstrings.
# ---> 43         self._check(obj, owner=owner)
#      44         out = MethodType(self.fn, obj)
#      46     else:
#      47         # This makes it possible to use the decorated method as an unbound method,
#      48         # for instance when monkeypatching.
#
# File c:\Users\rajmu\OneDrive\Desktop\ML\Scikit_Learn\.venv\Lib\site-packages\sklearn\utils\_available_if.py:34, in _AvailableIfDescriptor._check(self, obj, owner)
#      32     check_result = self.check(obj)
#      33 except Exception as e:
# ---> 34     raise AttributeError(attr_err_msg) from e
#      36 if not check_result:
#      37     raise AttributeError(attr_err_msg)
#
# AttributeError: This 'Pipeline' has no attribute 'fit_predict'
